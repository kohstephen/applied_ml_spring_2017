# %%
import pandas as pd
import mglearn
from sklearn.datasets import load_iris
iris_dataset = load_iris()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0)
# create dataframe from data in X_train
# label the columns using the strings in iris_dataset.feature_names
iris_dataframe = pd.DataFrame(X_train, columns=iris_dataset.feature_names)
# create a scatter matrix from the dataframe, color by y_train
grr = pd.scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15), marker='o',
hist_kwds={'bins': 20}, s=60, alpha=.8, cmap=mglearn.cm3)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-53005dc06be9> in <module>()
#       1 import pandas as pd
# ----> 2 import mglearn
#       3 from sklearn.datasets import load_iris
#       4 iris_dataset = load_iris()
#       5 from sklearn.model_selection import train_test_split
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/mglearn/__init__.py in <module>()
# ----> 1 from . import plots
#       2 from . import tools
#       3 from .plots import cm3, cm2
#       4 from .tools import discrete_scatter
#       5 from .plot_helpers import ReBl
#
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/mglearn/plots.py in <module>()
#       1 from .plot_linear_svc_regularization import plot_linear_svc_regularization
# ----> 2 from .plot_interactive_tree import plot_tree_progressive, plot_tree_partition
#       3 from .plot_animal_tree import plot_animal_tree
# ...

# %%
'''
Create a pair-plot of the iris dataset similar to Figure 1-3 in IMLP using only numpy and matplotlib. 

Ensure all axes are labeled. 

The diagonals need to contain histograms.

The different species need to be distinguished by color or glyph.

There needs to be a legend for the species.
'''

import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.lines as mlines
from sklearn.datasets import load_iris
iris_dataset = load_iris()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state=0)

fig = plt.figure(figsize=(5, 5))
plt.rcParams.update({'font.size': 6})
l = iris_dataset.feature_names

sub1 = plt.subplot(4, 4, 1)
sub1.set_xticks(())
sub1.set_yticks(())
sub1.set_ylabel(l[0])
n, bins, patches = plt.hist(X_train[:,0], 20, color='b', edgecolor='black', linewidth=0.5)

sub2 = plt.subplot(4, 4, 2)
sub2.set_xticks(())
# sub2.set_yticks(())
sub2.scatter(X_train[:,1], X_train[:,0], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub3 = plt.subplot(4, 4, 3)
sub3.set_xticks(())
sub3.set_yticks(())
sub3.scatter(X_train[:,2], X_train[:,0], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub4 = plt.subplot(4, 4, 4)
sub4.set_xticks(())
sub4.set_yticks(())
sub4.scatter(X_train[:,3], X_train[:,0], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub5 = plt.subplot(4, 4, 5)
sub5.set_xticks(())
# sub5.set_yticks(())
sub5.set_ylabel(l[1])
sub5.scatter(X_train[:,0], X_train[:,1], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub6 = plt.subplot(4, 4, 6)
sub6.set_xticks(())
sub6.set_yticks(())
n, bins, patches = plt.hist(X_train[:,1], 20, color='b', edgecolor='black', linewidth=0.5)

sub7 = plt.subplot(4, 4, 7)
sub7.set_xticks(())
sub7.set_yticks(())
sub7.scatter(X_train[:,2], X_train[:,1], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub8 = plt.subplot(4, 4, 8)
sub8.set_xticks(())
sub8.set_yticks(())
sub8.scatter(X_train[:,3], X_train[:,1], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub9 = plt.subplot(4, 4, 9)
sub9.set_xticks(())
# sub9.set_yticks(())
sub9.set_ylabel(l[2])
sub9.scatter(X_train[:,0], X_train[:,2], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub10 = plt.subplot(4, 4, 10)
sub10.set_xticks(())
sub10.set_yticks(())
sub10.scatter(X_train[:,1], X_train[:,2], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub11 = plt.subplot(4, 4, 11)
sub11.set_xticks(())
sub11.set_yticks(())
n, bins, patches = plt.hist(X_train[:,2], 20, color='b', edgecolor='black', linewidth=0.5)

sub12 = plt.subplot(4, 4, 12)
sub12.set_xticks(())
sub12.set_yticks(())
sub12.scatter(X_train[:,3], X_train[:,2], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub13 = plt.subplot(4, 4, 13)
# sub13.set_xticks(())
sub13.set_xlabel(l[0])
# sub13.set_yticks(())
sub13.set_ylabel(l[3])
sub13.scatter(X_train[:,0], X_train[:,3], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub14 = plt.subplot(4, 4, 14)
# sub14.set_xticks(())
sub14.set_xlabel(l[1])
sub14.set_yticks(())
sub14.scatter(X_train[:,1], X_train[:,3], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub15 = plt.subplot(4, 4, 15)
# sub15.set_xticks(())
sub15.set_xlabel(l[2])
sub15.set_yticks(())
sub15.scatter(X_train[:,2], X_train[:,3], c=y_train, cmap=cm.brg, s=10, alpha=.8, marker='o', edgecolors='k', linewidth=0.5)

sub16 = plt.subplot(4, 4, 16)
# sub16.set_xticks(())
sub16.set_xlabel(l[3])
sub16.set_yticks(())
n, bins, patches = plt.hist(X_train[:,3], 20, color='b', edgecolor='black', linewidth=0.5)

blue_dot = mlines.Line2D([], [], color='blue', marker='o',
                          markersize=5, label='setosa')
red_dot = mlines.Line2D([], [], color='red', marker='o',
                          markersize=5, label='versicolor')
green_dot = mlines.Line2D([], [], color='green', marker='o',
                          markersize=5, label='virginica')
plt.legend(handles=[blue_dot, red_dot, green_dot])

fig.tight_layout()
fig.subplots_adjust(wspace=0, hspace=0)

plt.show()

# create dataframe from data in X_train
# label the columns using the strings in iris_dataset.feature_names

# create a scatter matrix from the dataframe, color by y_train
# Out:
# <img src="data:image/png;base64,..." width="500">
